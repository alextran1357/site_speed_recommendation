# %%
import pandas as pd
import mlflow
mlflow.set_registry_uri("databricks-uc")

# %%
CATALOG_NAME = "workspace"
SCHEMA_NAME = "site-speed-recommendation"

# %%
data = spark.table("workspace.`site-speed-recommendation`.combined_dataset").toPandas()

# %%
data
