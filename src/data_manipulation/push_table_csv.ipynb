# %%
import pandas as pd

# %%
df = spark.sql('''
SELECT * 
FROM workspace.`site-speed-recommendation`.combined
''').toPandas()
df.to_csv("/Volumes/workspace/site-speed-recommendation/raw_data/test.csv")
